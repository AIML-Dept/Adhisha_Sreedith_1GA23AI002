# %% [markdown]
# <a href="https://colab.research.google.com/github/AIML-Dept/Adhisha_Sreedith_1GA23AI002/blob/main/Week_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Easy: Implement a CNOT gate circuit with the control qubit in state |1> and verify the target qubit flips**.

# %%
# !pip install qiskit qiskit-aer

from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator

qc = QuantumCircuit(2, 2)

# Put control qubit q0 into |1>
qc.x(0)

# CNOT: q0 = control, q1 = target
qc.cx(0, 1)

# Measure both qubits
qc.measure([0, 1], [0, 1])

print(qc)

simulator = AerSimulator()
result = simulator.run(qc, shots=1024).result()
print(result.get_counts())
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 13.0 MB/s eta 0:00:00
# ...
#      ┌───┐     ┌─┐
# q_0: ┤ X ├──■──┤M├───
#      └───┘┌─┴─┐└╥┘┌─┐
# q_1: ─────┤ X ├─╫─┤M├
#           └───┘ ║ └╥┘
# c: 2/═══════════╩══╩═
#                 0  1
# {'11': 1024}

# %% [markdown]
# # **Medium: Build a Bell state circuit and run 1024 shots, verifying the outcomes are only 00 and 11.**

# %%
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator

qc = QuantumCircuit(2, 2)

qc.h(0)
qc.cx(0, 1)

qc.measure([0, 1], [0, 1])

print(qc)

simulator = AerSimulator()
result = simulator.run(qc, shots=1024).result()
counts = result.get_counts()

print(counts)
# Out:
#      ┌───┐     ┌─┐
# q_0: ┤ H ├──■──┤M├───
#      └───┘┌─┴─┐└╥┘┌─┐
# q_1: ─────┤ X ├─╫─┤M├
#           └───┘ ║ └╥┘
# c: 2/═══════════╩══╩═
#                 0  1
# {'00': 521, '11': 503}

# %% [markdown]
# # **Hard: Implement a 3-qubit GHZ state and confirm perfect three-way correlation in measurement results.**

# %%
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator

qc = QuantumCircuit(3, 3)

qc.h(0)
qc.cx(0, 1)
qc.cx(1, 2)

qc.measure([0, 1, 2], [0, 1, 2])

print(qc)

simulator = AerSimulator()
result = simulator.run(qc, shots=1024).result()
counts = result.get_counts()

print(counts)
# Out:
#      ┌───┐          ┌─┐
# q_0: ┤ H ├──■───────┤M├──────
#      └───┘┌─┴─┐     └╥┘┌─┐
# q_1: ─────┤ X ├──■───╫─┤M├───
#           └───┘┌─┴─┐ ║ └╥┘┌─┐
# q_2: ──────────┤ X ├─╫──╫─┤M├
#                └───┘ ║  ║ └╥┘
# c: 3/════════════════╩══╩══╩═
#                      0  1  2
# {'000': 528, '111': 496}

# %% [markdown]
# # **Real World :- Emulate a classical full-adder circuit using Toffoli and CNOT gates.**

# %%
from qiskit import QuantumCircuit

qc = QuantumCircuit(5, 2)

# q0 = A
# q1 = B
# q2 = Cin
# q3 = Sum
# q4 = Carry

# Sum = A XOR B XOR Cin
qc.cx(0, 3)
qc.cx(1, 3)
qc.cx(2, 3)

# Carry = AB XOR Cin(A XOR B)
qc.ccx(0, 1, 4)
qc.cx(0, 3)
qc.ccx(3, 2, 4)
qc.cx(0, 3)

qc.measure(3, 0)
qc.measure(4, 1)

print(qc.draw())
# Out:
#
# q_0: ──■──────────────■────■─────────■─────
#        │              │    │         │
# q_1: ──┼────■─────────■────┼─────────┼─────
#        │    │         │    │         │
# q_2: ──┼────┼────■────┼────┼────■────┼─────
#      ┌─┴─┐┌─┴─┐┌─┴─┐  │  ┌─┴─┐  │  ┌─┴─┐┌─┐
# q_3: ┤ X ├┤ X ├┤ X ├──┼──┤ X ├──■──┤ X ├┤M├
#      └───┘└───┘└───┘┌─┴─┐└───┘┌─┴─┐└┬─┬┘└╥┘
# q_4: ───────────────┤ X ├─────┤ X ├─┤M├──╫─
#                     └───┘     └───┘ └╥┘  ║
# c: 2/════════════════════════════════╩═══╩═
#                                      1   0
